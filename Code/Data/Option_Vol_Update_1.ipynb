# %%
import os
from excelGen import excelOption
# Out:
# c:\users\gregg\appdata\local\programs\python\python38-32\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
tickers = ["SPY","XLK","MSFT"]
start_date = "2015-01-01"
end_date = None

data = excelOption(tickers, start_date, end_date)

bloomberg_functions = data.generateData()

bloomberg_functions["SPY"]
# Out:
#                                     SPY 3/20/15 C205    \
# 0  =BDH("SPY 3/20/15 C205 Equity","PX_LAST",20150...
#
#                                     SPY 4/17/15 C201    \
# 0  =BDH("SPY 4/17/15 C201 Equity","PX_LAST",20150...
#
#                                     SPY 5/15/15 C211    \
# 0  =BDH("SPY 5/15/15 C211 Equity","PX_LAST",20150...
#
#                                     SPY 6/19/15 C205    \
# 0  =BDH("SPY 6/19/15 C205 Equity","PX_LAST",20150...
#
#                                     SPY 7/17/15 C210    ...  \
# 0  =BDH("SPY 7/17/15 C210 Equity","PX_LAST",20150...    ...
#
#                                     SPY 6/19/20 C246    \
# 0  =BDH("SPY 6/19/20 C246 Equity","PX_LAST",20200...
#
#                                     SPY 7/17/20 C282    \
# 0  =BDH("SPY 7/17/20 C282 Equity","PX_LAST",20200...
#
#                                     SPY 8/21/20 C305    \
# 0  =BDH("SPY 8/21/20 C305 Equity","PX_LAST",20200...
#
# ...

# %%
bloomberg_functions["XLK"]
# Out:
#                                      XLK 3/20/15 C41    \
# 0  =BDH("XLK 3/20/15 C41 Equity","PX_LAST",201501...
#
#                                      XLK 4/17/15 C40    \
# 0  =BDH("XLK 4/17/15 C40 Equity","PX_LAST",201502...
#
#                                      XLK 5/15/15 C43    \
# 0  =BDH("XLK 5/15/15 C43 Equity","PX_LAST",201503...
#
#                                      XLK 6/19/15 C41    \
# 0  =BDH("XLK 6/19/15 C41 Equity","PX_LAST",201504...
#
#                                      XLK 7/17/15 C43    ...  \
# 0  =BDH("XLK 7/17/15 C43 Equity","PX_LAST",201505...    ...
#
#                                      XLK 6/19/20 C76    \
# 0  =BDH("XLK 6/19/20 C76 Equity","PX_LAST",202004...
#
#                                      XLK 7/17/20 C88    \
# 0  =BDH("XLK 7/17/20 C88 Equity","PX_LAST",202005...
#
#                                      XLK 8/21/20 C97    \
# 0  =BDH("XLK 8/21/20 C97 Equity","PX_LAST",202006...
#
# ...

# %%
bloomberg_functions["MSFT"]
# Out:
#                                     MSFT 3/20/15 C46    \
# 0  =BDH("MSFT 3/20/15 C46 Equity","PX_LAST",20150...
#
#                                     MSFT 4/17/15 C41    \
# 0  =BDH("MSFT 4/17/15 C41 Equity","PX_LAST",20150...
#
#                                     MSFT 5/15/15 C43    \
# 0  =BDH("MSFT 5/15/15 C43 Equity","PX_LAST",20150...
#
#                                     MSFT 6/19/15 C40    \
# 0  =BDH("MSFT 6/19/15 C40 Equity","PX_LAST",20150...
#
#                                     MSFT 7/17/15 C48    ...  \
# 0  =BDH("MSFT 7/17/15 C48 Equity","PX_LAST",20150...    ...
#
#                                    MSFT 6/19/20 C152    \
# 0  =BDH("MSFT 6/19/20 C152 Equity","PX_LAST",2020...
#
#                                    MSFT 7/17/20 C174    \
# 0  =BDH("MSFT 7/17/20 C174 Equity","PX_LAST",2020...
#
#                                    MSFT 8/21/20 C182    \
# 0  =BDH("MSFT 8/21/20 C182 Equity","PX_LAST",2020...
#
# ...
